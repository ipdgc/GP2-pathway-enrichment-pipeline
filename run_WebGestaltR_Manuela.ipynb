# %% [markdown]
# ## Set up and install packages if they are missing

# %%
# Utility routine for installing packages
install_if_missing <- function(packages) {
    if (length(setdiff(packages, rownames(installed.packages()))) > 0) {
        install.packages(setdiff(packages, rownames(installed.packages())))
    }
}

# %%
install_if_missing(c('tidyverse', 'viridis', 'ggthemes', 'pryr', 'skimr', 'testthat', 'reticulate', 'WebGestaltR', 'readxl'))

# %% [markdown]
# ## Load libraries

# %%
library(viridis)    # A nice color scheme for plots.
library(ggthemes)   # Common themes to change the look and feel of plots.
library(scales)     # Graphical scales map data to aesthetics in plots.
library(testthat)   # Testing functions.
library(assertthat) # Assertion functions.
library(pryr)       # Memory usage functions.
library(skimr)      # Summary statistics for dataframes.
library(bigrquery)  # BigQuery R client.
library(tidyverse)  # Data wrangling packages.
library(reticulate)  # R Interface to Python

library(Ronaldo)    # Leonardo R package.

library(data.table) # Data Table package for faster reading and processing


library(reticulate) # reticulate for calling the FireCloud Python API

library(ggplot2)    # Load ggplot2 for graphs

library(bigrquery)  # Load biqrquery for interacting with BigQuery

library(WebGestaltR)# For pathway/gene set enrichment analysis for this pipeline

library(readxl)

# %% [markdown]
# ## Set up environment variables

# %%
BILLING_PROJECT_ID <- Sys.getenv('GOOGLE_PROJECT')
WORKSPACE_NAMESPACE <- Sys.getenv('WORKSPACE_NAMESPACE')
WORKSPACE_NAME <- Sys.getenv('WORKSPACE_NAME')
WORKSPACE_BUCKET <-  Sys.getenv('WORKSPACE_BUCKET')

# %% [markdown]
# ## Set up utility functions

# %%
# Utility routine for printing a shell command before executing it
shell_do <- function(command) {
    print(paste('Executing: ', command))
    system(command, intern = TRUE)
}

# %%
# Utility routines for reading files from Google Cloud Storage
gcs_read_file <- function(path) {
    pipe(str_glue('gsutil -u {BILLING_PROJECT_ID} cat {path}'))
}
gcs_read_csv <- function(path, sep=',') {
    readr::read_csv(gcs_read_file(path))
}

# Utility routines for reading files from Google BigQuery
bq_query <- function(query) {
    # Return the contents of a query against BigQuery    
    return(bigrquery::bq_table_download(
        bigrquery::bq_project_query(BILLING_PROJECT_ID, query = query)))
}

# %% [markdown]
# ## Import GRCh37 gene coordinates into workspace

# %% [markdown]
# NCBI genome build 37.3 (this is an old version)
#
# Obtained from MAGMA auxilary files: https://ctg.cncr.nl/software/magma

# %%
shell_do(str_glue('gsutil -mu {BILLING_PROJECT_ID} cp {WORKSPACE_BUCKET}/NCBI37.3.zip ~/bin/data_temp/'))
# Out:
# [1] "Executing:  gsutil -mu gp2-ipdgc-hackathon cp gs://fc-secure-b9f9d17f-b38c-407d-85e0-7a759f13cea0/NCBI37.3.zip ~/bin/data_temp/"
# character(0)

# %%
#List files in ~/bin/data_temp/
system('ls ~/bin/data_temp/', intern=TRUE)
# Out:
# [1] "nallsEtAl2019_excluding23andMe_allVariants.tab"
# [2] "nallsEtAl2019_excluding23andMe_allVariants.tab.zip"
# [3] "NCBI37.3.zip"
# [4] "PDGWAS_for_FUMA_MT.txt"
# [5] "PDGWAS_for_FUMA_MT.txt.zip"
# [6] "test.zip"

# %%
#Unzip gene coordinates file
system('unzip ~/bin/data_temp/NCBI37.3.zip', intern=TRUE)
# Out:
# Warning message in system("unzip ~/bin/data_temp/NCBI37.3.zip", intern = TRUE):
# “running command 'unzip ~/bin/data_temp/NCBI37.3.zip' had status 1”
# [1] "Archive:  /home/jupyter-user/bin/data_temp/NCBI37.3.zip"
# attr(,"status")
# [1] 1
# attr(,"errmsg")
# [1] "Resource temporarily unavailable"

# %% [markdown]
# Download current genome build gene coordinates
#
# Downloaded from: http://ftp.ensembl.org/pub/grch37/current/gtf/homo_sapiens/

# %%
system('wget http://ftp.ensembl.org/pub/grch37/current/gtf/homo_sapiens/Homo_sapiens.GRCh37.87.gtf.gz')

# %%
system('ls', intern = TRUE)
# Out:
#  [1] "Anaconda3-2020.11-Linux-x86_64.sh"  "format_for_FUMA_Manuela.ipynb"
#  [3] "FUMA_format_input_file_Amica.ipynb" "Homo_sapiens.GRCh37.87.gtf"
#  [5] "import_GWAS_sumstats_Manuela.ipynb" "ldsc"
#  [7] "Miniconda3-latest-Linux-x86_64.sh"  "Miniconda3-latest-Linux-x86.sh"
#  [9] "NCBI37.3.gene.loc"                  "proj.ipynb"
# [11] "Python_Manuela.ipynb"               "README"
# [13] "REPORT"                             "run_WebGestaltR_Manuela.ipynb"
# [15] "stratified_LDSC_Manuela.ipynb"      "WebGestaltR_VI.ipynb"
# [17] "{WORKSPACE_BUCKET}"

# %%
system('gunzip Homo_sapiens.GRCh37.87.gtf.gz', intern=TRUE)
# Out:
# character(0)

# %% [markdown]
# ## Read in PD GWAS summary statistics

# %%
data <- fread("~/bin/data_temp/nallsEtAl2019_excluding23andMe_allVariants.tab", header = T)

# %%
head(data)
# Out:
#   SNP            A1 A2 freq   b       se     p      N_cases N_controls
# 1 chr11:88249377 T  C  0.9931  0.1575 0.1783 0.3771  7161     5356
# 2 chr1:60320992  A  G  0.9336  0.0605 0.0456 0.1846 26421   442271
# 3 chr2:18069070  T  C  0.9988 -0.6774 1.3519 0.6163   582      905
# 4 chr8:135908647 A  G  0.2081 -0.0358 0.0273 0.1887 26421   442271
# 5 chr12:3871714  A  C  0.9972  0.1489 1.0636 0.8886   749      658
# 6 chr16:77148858 A  G  0.9976 -0.1213 0.3874 0.7543  6248     4391

# %% [markdown]
# ## Filter for SNPs with p-value < 5e-08

# %%
data_filtered <- data %>%
    filter(p < 5e-08)

# %%
dim(data_filtered)
# Out:
# [1] 3464    9

# %% [markdown]
# ## Read in gene coordinates file and tidy

# %%
gene_coords <- fread("Homo_sapiens.GRCh37.87.gtf", skip = 5)

# %%
head(gene_coords)
# Out:
#   V1 V2             V3         V4    V5    V6 V7 V8
# 1 1  ensembl_havana gene       11869 14412 .  +  .
# 2 1  havana         transcript 11869 14409 .  +  .
# 3 1  havana         exon       11869 12227 .  +  .
# 4 1  havana         exon       12613 12721 .  +  .
# 5 1  havana         exon       13221 14409 .  +  .
# 6 1  ensembl        transcript 11872 14412 .  +  .
#   V9
# 1 gene_id "ENSG00000223972"; gene_version "4"; gene_name "DDX11L1"; gene_source "ensembl_havana"; gene_biotype "pseudogene";
# 2 gene_id "ENSG00000223972"; gene_version "4"; transcript_id "ENST00000456328"; transcript_version "2"; gene_name "DDX11L1"; gene_source "ensembl_havana"; gene_biotype "pseudogene"; transcript_name "DDX11L1-002"; transcript_source "havana"; transcript_biotype "processed_transcript"; havana_transcript "OTTHUMT00000362751"; havana_transcript_version "1"; tag "basic";
# 3 gene_id "ENSG00000223972"; gene_version "4"; transcript_id "ENST00000456328"; transcript_version "2"; exon_number "1"; gene_name "DDX11L1"; gene_source "ensembl_havana"; gene_biotype "pseudogene"; transcript_name "DDX11L1-002"; transcript_source "havana"; transcript_biotype "processed_transcript"; havana_transcript "OTTHUMT00000362751"; havana_transcript_version "1"; exon_id "ENSE00002234944"; exon_version "1"; tag "basic";
# 4 gene_id "ENSG00000223972"; gene_version "4"; transcript_id "ENST00000456328"; transcript_version "2"; exon_number "2"; gene_name "DDX11L1"; gene_source "ensembl_havana"; gene_biotype "pseudogene"; transcript_name "DDX11L1-002"; transcript_source "havana"; transcript_biotype "processed_transcript"; havana_transcript "OTTHUMT00000362751"; havana_transcript_version "1"; exon_id "ENSE00003582793"; exon_version "1"; tag "basic";
# 5 gene_id "ENSG00000223972"; gene_version "4"; transcript_id "ENST00000456328"; transcript_version "2"; exon_number "3"; gene_name "DDX11L1"; gene_source "ensembl_havana"; gene_biotype "pseudogene"; transcript_name "DDX11L1-002"; transcript_source "havana"; transcript_biotype "processed_transcript"; havana_transcript "OTTHUMT00000362751"; havana_transcript_version "1"; exon_id "ENSE00002312635"; exon_version "1"; tag "basic";
# 6 gene_id "ENSG00000223972"; gene_version "4"; transcript_id "ENST00000515242"; transcript_version "2"; gene_name "DDX11L1"; gene_source "ensembl_havana"; gene_biotype "pseudogene"; transcript_name "DDX11L1-201"; transcript_source "ensembl"; transcript_biotype "transcribed_unprocessed_pseudogene";

# %% [markdown]
# Filter just for genes

# %%
gene_coords_genesonly <- gene_coords %>%
    filter(V3 == "gene")

# %%
head(gene_coords_genesonly)
# Out:
#   V1 V2             V3   V4    V5    V6 V7 V8
# 1 1  ensembl_havana gene 11869 14412 .  +  .
# 2 1  ensembl_havana gene 14363 29806 .  -  .
# 3 1  ensembl_havana gene 29554 31109 .  +  .
# 4 1  ensembl_havana gene 34554 36081 .  -  .
# 5 1  ensembl_havana gene 52473 54936 .  +  .
# 6 1  havana         gene 62948 63887 .  +  .
#   V9
# 1 gene_id "ENSG00000223972"; gene_version "4"; gene_name "DDX11L1"; gene_source "ensembl_havana"; gene_biotype "pseudogene";
# 2 gene_id "ENSG00000227232"; gene_version "4"; gene_name "WASH7P"; gene_source "ensembl_havana"; gene_biotype "pseudogene";
# 3 gene_id "ENSG00000243485"; gene_version "2"; gene_name "MIR1302-10"; gene_source "ensembl_havana"; gene_biotype "lincRNA";
# 4 gene_id "ENSG00000237613"; gene_version "2"; gene_name "FAM138A"; gene_source "ensembl_havana"; gene_biotype "lincRNA";
# 5 gene_id "ENSG00000268020"; gene_version "2"; gene_name "OR4G4P"; gene_source "ensembl_havana"; gene_biotype "pseudogene";
# 6 gene_id "ENSG00000240361"; gene_version "1"; gene_name "OR4G11P"; gene_source "havana"; gene_biotype "pseudogene";

# %% [markdown]
# Separate column 9 to get gene names

# %%
setDT(gene_coords_genesonly)[, c("gene_id", "gene_version", "gene_name", "gene_source", "gene_biotype") := tstrsplit(V9, ";")]

# %%
head(gene_coords_genesonly)
# Out:
#   V1 V2             V3   V4    V5    V6 V7 V8
# 1 1  ensembl_havana gene 11869 14412 .  +  .
# 2 1  ensembl_havana gene 14363 29806 .  -  .
# 3 1  ensembl_havana gene 29554 31109 .  +  .
# 4 1  ensembl_havana gene 34554 36081 .  -  .
# 5 1  ensembl_havana gene 52473 54936 .  +  .
# 6 1  havana         gene 62948 63887 .  +  .
#   V9
# 1 gene_id "ENSG00000223972"; gene_version "4"; gene_name "DDX11L1"; gene_source "ensembl_havana"; gene_biotype "pseudogene";
# 2 gene_id "ENSG00000227232"; gene_version "4"; gene_name "WASH7P"; gene_source "ensembl_havana"; gene_biotype "pseudogene";
# 3 gene_id "ENSG00000243485"; gene_version "2"; gene_name "MIR1302-10"; gene_source "ensembl_havana"; gene_biotype "lincRNA";
# 4 gene_id "ENSG00000237613"; gene_version "2"; gene_name "FAM138A"; gene_source "ensembl_havana"; gene_biotype "lincRNA";
# 5 gene_id "ENSG00000268020"; gene_version "2"; gene_name "OR4G4P"; gene_source "ensembl_havana"; gene_biotype "pseudogene";
# 6 gene_id "ENSG00000240361"; gene_version "1"; gene_name "OR4G11P"; gene_source "havana"; gene_biotype "pseudogene";
#   gene_id                   gene_version      gene_name
# 1 gene_id "ENSG00000223972"  gene_version "4"  gene_name "DDX11L1"
# 2 gene_id "ENSG00000227232"  gene_version "4"  gene_name "WASH7P"
# 3 gene_id "ENSG00000243485"  gene_version "2"  gene_name "MIR1302-10"
# 4 gene_id "ENSG00000237613"  gene_version "2"  gene_name "FAM138A"
# 5 gene_id "ENSG00000268020"  gene_version "2"  gene_name "OR4G4P"
# 6 gene_id "ENSG00000240361"  gene_version "1"  gene_name "OR4G11P"
#   gene_source                   gene_biotype
# 1  gene_source "ensembl_havana"  gene_biotype "pseudogene"
# 2  gene_source "ensembl_havana"  gene_biotype "pseudogene"
# 3  gene_source "ensembl_havana"  gene_biotype "lincRNA"
# 4  gene_source "ensembl_havana"  gene_biotype "lincRNA"
# 5  gene_source "ensembl_havana"  gene_biotype "pseudogene"
# 6  gene_source "havana"          gene_biotype "pseudogene"

# %%
gene_coords_genesonly_select <- gene_coords_genesonly %>%
    select(V1, V4, V5, gene_name) %>% #Select just relevant columns - chr, bp start, bp end, gene name
    mutate(gene = gsub("gene_name", "", gene_name)) %>% #Remove string 'gene_name' from the gene_name col
    mutate(gene_final = gsub('"', "", gene)) #Remove the "" from gene column and make gene_final col

# %%
head(gene_coords_genesonly_select)
# Out:
#   V1 V4    V5    gene_name               gene           gene_final
# 1 1  11869 14412  gene_name "DDX11L1"      "DDX11L1"      DDX11L1
# 2 1  14363 29806  gene_name "WASH7P"       "WASH7P"       WASH7P
# 3 1  29554 31109  gene_name "MIR1302-10"   "MIR1302-10"   MIR1302-10
# 4 1  34554 36081  gene_name "FAM138A"      "FAM138A"      FAM138A
# 5 1  52473 54936  gene_name "OR4G4P"       "OR4G4P"       OR4G4P
# 6 1  62948 63887  gene_name "OR4G11P"      "OR4G11P"      OR4G11P

# %% [markdown]
# Select only relevant columns and rename

# %%
gene_coords_final <- gene_coords_genesonly_select %>%
    select(V1, V4, V5, gene_final) %>%
    rename(chr = V1,
          bp_start = V4,
          bp_end = V5,
          gene = gene_final)

# %%
head(gene_coords_final)
# Out:
#   chr bp_start bp_end gene
# 1 1   11869    14412    DDX11L1
# 2 1   14363    29806    WASH7P
# 3 1   29554    31109    MIR1302-10
# 4 1   34554    36081    FAM138A
# 5 1   52473    54936    OR4G4P
# 6 1   62948    63887    OR4G11P

# %% [markdown]
# ## Annotate GWAS sumstats with nearest genes

# %%
tail(data_filtered)
# Out:
#   SNP            A1 A2 freq   b       se     p         N_cases N_controls
# 1 chr5:60345424  T  G  0.8883 -0.1916 0.0266 5.618e-13 33674   449056
# 2 chr17:43758382 T  C  0.7814  0.2527 0.0269 5.906e-21 32505   448088
# 3 chr17:44201667 A  G  0.2176 -0.2554 0.0271 4.138e-21 32505   448088
# 4 chr12:40556767 T  C  0.9971 -4.0052 0.5940 1.554e-11  8488     7671
# 5 chr17:43858187 T  G  0.2187 -0.2521 0.0270 8.896e-21 32505   448088
# 6 chr17:43992233 T  C  0.2171 -0.2510 0.0271 1.749e-20 32505   448088

# %% [markdown]
# ## Read in GWAS top hits annotated with nearest genes

# %% [markdown]
# First import file into workspace

# %%
shell_do(str_glue('gsutil -mu {BILLING_PROJECT_ID} cp {WORKSPACE_BUCKET}/"Table S2. Detailed summary statistics.xlsx" ~/bin/data_temp/'))
# Out:
# [1] "Executing:  gsutil -mu gp2-ipdgc-hackathon cp gs://fc-secure-b9f9d17f-b38c-407d-85e0-7a759f13cea0/\"Table S2. Detailed summary statistics.xlsx\" ~/bin/data_temp/"
# character(0)

# %%
system('ls ~/bin/data_temp', intern = TRUE)
# Out:
# [1] "nallsEtAl2019_excluding23andMe_allVariants.tab"
# [2] "nallsEtAl2019_excluding23andMe_allVariants.tab.zip"
# [3] "NCBI37.3.zip"
# [4] "PDGWAS_for_FUMA_MT.txt"
# [5] "PDGWAS_for_FUMA_MT.txt.zip"
# [6] "Table S2. Detailed summary statistics.xlsx"
# [7] "test.zip"

# %% [markdown]
# Read GWAS hits into R

# %%
GWAS_toploci <- read_xlsx("~/bin/data_temp/Table S2. Detailed summary statistics.xlsx")

# %%
head(GWAS_toploci)
# Out:
#   SNP         CHR BP        Nearest Gene QTL Nominated Gene (nearest QTL)
# 1 rs114138760 1   154898185 PMVK         NA
# 2 rs35749011  1   155135036 KRTCAP2      NA
# 3 rs76763715  1   155205634 GBAP1        GBAP1
# 4 rs6658353   1   161469054 FCGR2A       FCGR2A
# 5 rs11578699  1   171719769 VAMP4        VAMP4
# 6 rs823118    1   205723572 NUCKS1       NUCKS1
#   Effect allele Other allele Effect allele frequency Beta, all studies
# 1 c             g            0.0112                   0.2812
# 2 a             g            0.0169                   0.6068
# 3 t             c            0.9953                  -0.7467
# 4 c             g            0.5011                   0.0650
# 5 t             c            0.1949                  -0.0704
# 6 t             c            0.5660                   0.1066
#   SE, all studies ⋯ Freq1, new studies Beta, new studies StdErr, new studies
# 1 0.0478          ⋯ 0.0109              0.1997           0.0843
# 2 0.0342          ⋯ 0.0177              0.6798           0.0615
# 3 0.0765          ⋯ 0.9941             -0.6693           0.1269
# 4 0.0094          ⋯ 0.5105              0.0662           0.0171
# 5 0.0120          ⋯ 0.1947             -0.0663           0.0226
# 6 0.0094          ⋯ 0.5674              0.0842           0.0172
#   P, new studies I2, new studies Passes pooled 23andMe QC
# 1 1.779e-02       0.0            T
# 2 2.160e-28       0.0            T
# 3 1.340e-07       0.0            F
# 4 1.101e-04      46.4            T
# 5 3.313e-03      13.4            T
# 6 1.020e-06       0.0            T
#   Known GWAS locus within 1MB Failed final filtering and QC Locus within 250KB
# 1 1                           0                             1
# 2 1                           0                             1
# 3 1                           0                             1
# 4 0                           0                             0
# 5 0                           0                             0
# 6 1                           0                             1
#   Locus Number
# 1 1
# 2 1
# 3 1
# 4 2
# 5 3
# 6 4

# %% [markdown]
# Make list of SNPs in .txt file

# %%
SNPs_only <- GWAS_toploci %>%
    select(SNP) %>%
    arrange('P, all studies')

# %%
write.table(SNPs_only, "~/bin/data_temp/PDSNPs_sorted.txt", quote = F, row.names = F, col.names = F, sep = "\t")

# %%
system('ls ~/bin/data_temp/', intern = TRUE)
# Out:
# [1] "nallsEtAl2019_excluding23andMe_allVariants.tab"
# [2] "nallsEtAl2019_excluding23andMe_allVariants.tab.zip"
# [3] "NCBI37.3.zip"
# [4] "PDgenes_sorted_geneonly.txt"
# [5] "PDGWAS_for_FUMA_MT.txt"
# [6] "PDGWAS_for_FUMA_MT.txt.zip"
# [7] "PDSNPs_sorted.txt"
# [8] "Table S2. Detailed summary statistics.xlsx"
# [9] "test.zip"

# %% [markdown]
# ## Make gene list ranked by p-values

# %%
PDgenes <- GWAS_toploci %>%
    select('Nearest Gene', 'P, all studies') %>%
    rename(gene = 'Nearest Gene',
          p = 'P, all studies')

# %%
head(PDgenes)
# Out:
#   gene    p
# 1 PMVK    4.19e-09
# 2 KRTCAP2 1.72e-70
# 3 GBAP1   1.59e-22
# 4 FCGR2A  6.10e-12
# 5 VAMP4   4.47e-09
# 6 NUCKS1  1.11e-29

# %% [markdown]
# Remove any missing nearest gene and rank by p-value

# %%
PDgenes_sorted <- PDgenes %>%
    filter(!is.na(gene)) %>%
    arrange(p)

# %%
head(PDgenes_sorted)
# Out:
#   gene    p
# 1 SNCA    3.89e-154
# 2 SNCA    5.16e-149
# 3 LRRK2   3.61e-148
# 4 KRTCAP2  1.72e-70
# 5 TMEM175  9.98e-70
# 6 CRHR1    3.58e-68

# %%
write.table(PDgenes_sorted, "~/bin/data_temp/PDgenes_sorted_pvals.rnk",
           quote = F, col.names = F, row.names = F, sep = "\t")

# %% [markdown]
# Make a dataframe with genes and -log10 pvalues

# %%
PDgenes_sorted_neglogp <- PDgenes_sorted %>%
    mutate(neg_log10p = -log10(p))

# %%
head(PDgenes_sorted_neglogp)
# Out:
#   gene    p         neg_log10p
# 1 SNCA    3.89e-154 153.41005
# 2 SNCA    5.16e-149 148.28735
# 3 LRRK2   3.61e-148 147.44249
# 4 KRTCAP2  1.72e-70  69.76447
# 5 TMEM175  9.98e-70  69.00087
# 6 CRHR1    3.58e-68  67.44612

# %%
PDgenes_sorted_neglogp <- PDgenes_sorted_neglogp %>%
    select(gene, neg_log10p)

#Export as rnk file
write.table(PDgenes_sorted_neglogp, "~/bin/data_temp/PDgenes_sorted_pvals_neglog.rnk",
           quote = F, col.names = F, row.names = F, sep = "\t")

# %% [markdown]
# Make a dataframe with just the unique gene names

# %%
PDgenes_sorted_geneonly <- PDgenes_sorted %>%
    select(gene) %>%
    distinct(gene)

# %%
write.table(PDgenes_sorted_geneonly, "~/bin/data_temp/PDgenes_sorted_geneonly.txt",
           quote = F, col.names = F, row.names = F, sep = "/n")

# %%
system('head ~/bin/data_temp/PDgenes_sorted_geneonly.txt', intern = TRUE)
# Out:
#  [1] "SNCA"     "LRRK2"    "KRTCAP2"  "TMEM175"  "CRHR1"    "NSF"
#  [7] "KANSL1"   "STK39"    "MAPT-AS1" "HIP1R"

# %% [markdown]
# Write gene list to workspace bucket to check

# %%
shell_do(str_glue('gsutil -u {BILLING_PROJECT_ID} cp -r ~/bin/data_temp/PDgenes_sorted_geneonly.txt {WORKSPACE_BUCKET}'))
# Out:
# [1] "Executing:  gsutil -u gp2-ipdgc-hackathon cp -r ~/bin/data_temp/PDgenes_sorted_geneonly.txt gs://fc-secure-b9f9d17f-b38c-407d-85e0-7a759f13cea0"
# character(0)

# %% [markdown]
# ## Show WebGestaltR options

# %%
listReferenceSet(
organism = "hsapiens",
hostName = "http://www.webgestalt.org/",
cache = NULL
)
# Out:
#  [1] "affy_Axiom_BioBank1"              "affy_Axiom_PMRA"
#  [3] "affy_Axiom_tx_v1"                 "affy_GenomeWideSNP_5"
#  [5] "affy_GenomeWideSNP_6"             "affy_Mapping10K_Xba142"
#  [7] "affy_Mapping250K_Nsp"             "affy_Mapping250K_Sty"
#  [9] "affy_Mapping50K_Hind240"          "affy_Mapping50K_Xba240"
# [11] "affy_OncoScan"                    "affy_RosettaMerck_Human_RSTA"
# [13] "affy_hc_g110"                     "affy_hg_focus"
# [15] "affy_hg_u133_plus_2"              "affy_hg_u133a"
# [17] "affy_hg_u133a_2"                  "affy_hg_u133b"
# [19] "affy_hg_u95a"                     "affy_hg_u95av2"
# [21] "affy_hg_u95b"                     "affy_hg_u95c"
# [23] "affy_hg_u95d"                     "affy_hg_u95e"
# [25] "affy_hta_2_0"                     "affy_huex_1_0_st_v2"
# [27] "affy_hugene_1_0_st_v1"            "affy_hugene_2_0_st_v1"
# [29] "affy_hugenefl"                    "affy_primeview"
# [31] "affy_u133_x3p"                    "agilent_cgh_44b"
# [33] "agilent_gpl6848"                  "agilent_sureprint_g3_ge_8x60k"
# [35] "agilent_sureprint_g3_ge_8x60k_v2" "agilent_wholegenome"
# [37] "agilent_wholegenome_4x44k_v1"     "agilent_wholegenome_4x44k_v2"
# [39] "codelink_codelink"                "genome"
# [41] "genome_protein-coding"            "illumina_humanht_12_v3"
# [43] "illumina_humanht_12_v4"           "illumina_humanref_8_v3"
# [45] "illumina_humanwg_6_v1"            "illumina_humanwg_6_v2"
# [47] "illumina_humanwg_6_v3"            "phalanx_onearray"
# [49] "phosphosite"

# %%
listIdType(organism="hsapiens")
# Out:
#  [1] "The_Genotype-Tissue_ExpressionProjectGTEx"
#  [2] "affy_Axiom_BioBank1"
#  [3] "affy_Axiom_PMRA"
#  [4] "affy_Axiom_tx_v1"
#  [5] "affy_GenomeWideSNP_5"
#  [6] "affy_GenomeWideSNP_6"
#  [7] "affy_Mapping10K_Xba142"
#  [8] "affy_Mapping250K_Nsp"
#  [9] "affy_Mapping250K_Sty"
# [10] "affy_Mapping50K_Hind240"
# [11] "affy_Mapping50K_Xba240"
# [12] "affy_OncoScan"
# [13] "affy_RosettaMerck_Human_RSTA"
# [14] "affy_hc_g110"
# [15] "affy_hg_focus"
# [16] "affy_hg_u133_plus_2"
# [17] "affy_hg_u133a"
# [18] "affy_hg_u133a_2"
# [19] "affy_hg_u133b"
# [20] "affy_hg_u95a"
# [21] "affy_hg_u95av2"
# [22] "affy_hg_u95b"
# [23] "affy_hg_u95c"
# [24] "affy_hg_u95d"
# [25] "affy_hg_u95e"
# [26] "affy_hta_2_0"
# [27] "affy_huex_1_0_st_v2"
# [28] "affy_hugene_1_0_st_v1"
# [29] "affy_hugene_2_0_st_v1"
# [30] "affy_hugenefl"
# [31] "affy_primeview"
# [32] "affy_u133_x3p"
# [33] "agilent_cgh_44b"
# [34] "agilent_custom_SAGE_Bionetworks_GPL564"
# [35] "agilent_gpl6848"
# [36] "agilent_human_custom_GPL564"
# [37] "agilent_sureprint_g3_ge_8x60k"
# [38] "agilent_sureprint_g3_ge_8x60k_v2"
# [39] "agilent_wholegenome"
# [40] "agilent_wholegenome_4x44k_v1"
# [41] "agilent_wholegenome_4x44k_v2"
# [42] "codelink_codelink"
# [43] "dbSNP"
# [44] "embl"
# [45] "ensembl_gene_id"
# [46] "ensembl_peptide_id"
# [47] "entrezgene"
# [48] "entrezgene_protein-coding"
# [49] "genename"
# [50] "genesymbol"
# [51] "illumina_Infinium_HumanMethylation_beadchip"
# [52] "illumina_Sentrix_HumanRef-8v2_GPL2700"
# [53] "illumina_human-6v3"
# [54] "illumina_humanRef-8v2"
# [55] "illumina_human_methylation_27"
# [56] "illumina_human_methylation_450"
# [57] "illumina_humanht_12_v3"
# [58] "illumina_humanht_12_v4"
# [59] "illumina_humanref_8_v3"
# [60] "illumina_humanwg_6_v1"
# [61] "illumina_humanwg_6_v2"
# [62] "illumina_humanwg_6_v3"
# [63] "interpro"
# [64] "phalanx_onearray"
# [65] "phosphositeEnsembl"
# [66] "phosphositeRefseq"
# [67] "phosphositeSeq"
# [68] "phosphositeUniprot"
# [69] "protein_id"
# [70] "refseq_mrna"
# [71] "refseq_peptide"
# [72] "unigene"
# [73] "uniprotswissprot"

# %%
listGeneSet(organism = "hsapiens")
# Out:
#    name
# 1  geneontology_Biological_Process
# 2  geneontology_Biological_Process_noRedundant
# 3  geneontology_Cellular_Component
# 4  geneontology_Cellular_Component_noRedundant
# 5  geneontology_Molecular_Function
# 6  geneontology_Molecular_Function_noRedundant
# 7  pathway_KEGG
# 8  pathway_Panther
# 9  pathway_Reactome
# 10 pathway_Wikipathway
# 11 pathway_Wikipathway_cancer
# 12 network_CORUM
# 13 network_CPTAC_Proteomics_BRCA
# 14 network_CPTAC_Proteomics_COADREAD
# 15 network_CPTAC_Proteomics_OV
# 16 network_Kinase_phosphosite
# 17 network_Kinase_target
# 18 network_PPI_BIOGRID
# 19 network_PTMsigDB
# 20 network_TCGA_RNASeq_ACC
# 21 network_TCGA_RNASeq_BLCA
# 22 network_TCGA_RNASeq_BRCA
# 23 network_TCGA_RNASeq_CESC
# 24 network_TCGA_RNASeq_CHOL
# 25 network_TCGA_RNASeq_COADREAD
# 26 network_TCGA_RNASeq_DLBC
# 27 network_TCGA_RNASeq_ESCA
# 28 network_TCGA_RNASeq_GBM
# 29 network_TCGA_RNASeq_GBMLGG
# 30 network_TCGA_RNASeq_HNSC
# ⋮  ⋮
# 35 network_TCGA_RNASeq_LIHC
# 36 network_TCGA_RNASeq_LUAD
# 37 network_TCGA_RNASeq_LUSC
# 38 network_TCGA_RNASeq_MESO
# 39 network_TCGA_RNASeq_OV
# 40 network_TCGA_RNASeq_PAAD
# 41 network_TCGA_RNASeq_PCPG
# 42 network_TCGA_RNASeq_PRAD
# 43 network_TCGA_RNASeq_SARC
# 44 network_TCGA_RNASeq_SKCM
# 45 network_TCGA_RNASeq_STAD
# 46 network_TCGA_RNASeq_STES
# 47 network_TCGA_RNASeq_TGCT
# 48 network_TCGA_RNASeq_THCA
# 49 network_TCGA_RNASeq_THYM
# 50 network_TCGA_RNASeq_UCEC
# 51 network_TCGA_RNASeq_UCS
# 52 network_TCGA_RNASeq_UVM
# 53 network_Transcription_Factor_target
# 54 network_miRNA_target
# 55 disease_Disgenet
# 56 disease_GLAD4U
# 57 disease_OMIM
# 58 drug_DrugBank
# 59 drug_GLAD4U
# 60 phenotype_Human_Phenotype_Ontology
# 61 chromosomalLocation_CytogeneticBand
# 62 community-contributed_5htGeneSets_Conte
# 63 community-contributed_Hallmark50
# 64 community-contributed_MuscleGeneSets_Duddy_2017
#    description
# 1  The gene ontology biological process database was downloaded from http://www.geneontology.org/.
# 2  The gene ontology biological process database was downloaded from http://www.geneontology.org/. Then, we only contain the non-redundant categories by selecting the most general categories in each branch of the GO DAG structure from all categories with the number of annotated genes from 20 to 500.
# 3  The gene ontology cellular component database was downloaded from http://www.geneontology.org/.
# 4  The gene ontology cellular component database was downloaded from http://www.geneontology.org/. Then, we only contain the non-redundant categories by selecting the most general categories in each branch of the GO DAG structure from all categories with the number of annotated genes from 20 to 500.
# 5  The gene ontology molecular function database was downloaded from http://www.geneontology.org/.
# 6  The gene ontology molecular function database was downloaded from http://www.geneontology.org/. Then, we only contain the non-redundant categories by selecting the most general categories in each branch of the GO DAG structure from all categories with the number of annotated genes from 20 to 500.
# 7  The KEGG pathway database was downloaded from http://www.kegg.jp/.
# 8  The PANTHER pathway database was downloaded from http://www.pantherdb.org/pathway/.
# 9  The Reactome pathway database was downloaded from http://www.reactome.org/.
# 10 The Wikipathway database was downloaded from http://www.wikipathway.org/.
# 11 The Wikipathway database was downloaded from http://www.wikipathway.org/. This is the subset relevant to Clinical Proteomic Tumor Analysis Consortium.
# 12 The core complex subunits were downloaded from CORUM database (https://mips.helmholtz-muenchen.de/corum/#).
# 13 The BRCA (Breast invasive carcinoma) Proteomics data was downloaded from CPTAC (Clinical Proteomic Tumor Analysis Consortium) data portal (https://cptac-data-portal.georgetown.edu/cptacPublic/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus Proteomics co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 14 The COADREAD (Colorectal adenocarcinoma) Proteomics data was downloaded from CPTAC (Clinical Proteomic Tumor Analysis Consortium) data portal (https://cptac-data-portal.georgetown.edu/cptacPublic/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus Proteomics co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 15 The OV (Ovarian serous cystadenocarcinoma) Proteomics data was downloaded from CPTAC (Clinical Proteomic Tumor Analysis Consortium) data portal (https://cptac-data-portal.georgetown.edu/cptacPublic/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus Proteomics co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 16 The relationship between Kinase and the corresponding protein phosposite position was from RegPhos (http://140.138.144.141/~RegPhos/). Then, we got the 15-mer sequence window around the phosphorylated site of the peptide (up and down 7 amino acid) from the Uniprot website (http://www.uniprot.org/) as the identifier tag.
# 17 The relationship between Kinase and its targets was from PhosphositePlus (http://www.phosphosite.org/) and the phosphorylation relationships from a in-house combined signaling network.
# 18 The protein-protein interaction (PPI) network was downloaded from BIOGRID (https://thebiogrid.org/). Then, we used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 19 The database was downloaded from the PTM signatures database (https://github.com/broadinstitute/ssGSEA2.0). Direction of change is removed.
# 20 The ACC (Adrenocortical carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 21 The BLCA (Bladder Urothelial Carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 22 The BRCA (Breast invasive carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 23 The CESC (Cervical squamous cell carcinoma and endocervical adenocarcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 24 The CHOL (Cholangiocarcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 25 The COADREAD (Colon and rectal cancer) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 26 The DLBC (Lymphoid Neoplasm Diffuse Large B-cell Lymphoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 27 The ESCA (Esophageal carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 28 The GBM (Glioblastoma multiforme) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 29 The GBMLGG (Glioma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 30 The HNSC (Head and Neck squamous cell carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# ⋮  ⋮
# 35 The LIHC (Liver hepatocellular carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 36 The LUAD (Lung adenocarcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 37 The LUSC (Lung squamous cell carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 38 The MESO (Mesothelioma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 39 The OV (Ovarian serous cystadenocarcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 40 The PAAD (Pancreatic adenocarcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 41 The PCPG (Pheochromocytoma and Paraganglioma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 42 The PRAD (Prostate adenocarcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 43 The SARC (Sarcoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 44 The SKCM (Skin Cutaneous Melanoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 45 The STAD (Stomach adenocarcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 46 The STES (Stomach and Esophageal carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 47 The TGCT (Testicular Germ Cell Tumors) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 48 The THCA (Thyroid carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 49 The THYM (Thymoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 50 The UCEC (Uterine Corpus Endometrial Carcinoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 51 The UCS (Uterine Carcinosarcoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 52 The UVM (Uveal Melanoma) RNASeq data was downloaded from TCGA (The Cancer Genome Atlas) firehose data portal (https://gdac.broadinstitute.org/). Then, based on the method described in our recently published paper (PMID: 27836980), we first constructed the consensus RNASeq co-expression network and then used the NetSAM R package (http://bioconductor.org/packages/release/bioc/html/NetSAM.html) to identify the hierarchical co-expression modules.
# 53 The relationship between transcription factor and its targets was downloaded from MsigDB (http://software.broadinstitute.org/gsea/msigdb).
# 54 The relationship between miRNA and its targets was downloaded from MsigDB (http://software.broadinstitute.org/gsea/msigdb).
# 55 The DisgeNET disease database was downloaded from http://www.disgenet.org.
# 56 Disease terms were downloaded from ParmGKB (https://www.pharmgkb.org/). Genes associated with individual disease term were inferred using GLAD4U (http://glad4u.zhang-lab.org/index.php).
# 57
# 58 The DrugBank drug database was downloaded from https://www.drugbank.ca/.
# 59 Drug terms were downloaded from ParmGKB (https://www.pharmgkb.org/). Genes associated with individual drug term were inferred using GLAD4U (http://glad4u.zhang-lab.org/index.php).
# 60 The phenotype ontology information for human was downloaded from http://human-phenotype-ontology.github.io/.
# 61
# 62
# 63 Hallmark gene sets summarize and represent specific well-defined biological states or processes and display coherent expression. See details at http://software.broadinstitute.org/gsea/msigdb/collections.jsp#H .
# 64 Muscle Gene Sets (v3) Duddy 2017
#    idType
# 1  entrezgene
# 2  entrezgene
# 3  entrezgene
# 4  entrezgene
# 5  entrezgene
# 6  entrezgene
# 7  entrezgene
# 8  entrezgene
# 9  entrezgene
# 10 entrezgene
# 11 entrezgene
# 12 entrezgene
# 13 entrezgene
# 14 entrezgene
# 15 entrezgene
# 16 phosphositeSeq
# 17 entrezgene
# 18 entrezgene
# 19 phosphositeSeq
# 20 entrezgene
# 21 entrezgene
# 22 entrezgene
# 23 entrezgene
# 24 entrezgene
# 25 entrezgene
# 26 entrezgene
# 27 entrezgene
# 28 entrezgene
# 29 entrezgene
# 30 entrezgene
# ⋮  ⋮
# 35 entrezgene
# 36 entrezgene
# 37 entrezgene
# 38 entrezgene
# 39 entrezgene
# 40 entrezgene
# 41 entrezgene
# 42 entrezgene
# 43 entrezgene
# 44 entrezgene
# 45 entrezgene
# 46 entrezgene
# 47 entrezgene
# 48 entrezgene
# 49 entrezgene
# 50 entrezgene
# 51 entrezgene
# 52 entrezgene
# 53 entrezgene
# 54 entrezgene
# 55 entrezgene
# 56 entrezgene
# 57 entrezgene
# 58 entrezgene
# 59 entrezgene
# 60 entrezgene
# 61 entrezgene
# 62 entrezgene
# 63 entrezgene
# 64 entrezgene

# %% [markdown]
# ## Run WebGestaltR Overrepresentation Analysis (ORA)

# %% [markdown]
# Run with gene list

# %%
refFile <- system.file("extdata", "referenceGenes.txt", package="WebGestaltR")
enrichResult <- WebGestaltR(enrichMethod="ORA", organism="hsapiens",
                            enrichDatabase="pathway_KEGG", interestGeneFile="~/bin/data_temp/PDgenes_sorted_geneonly.txt",
                            interestGeneType="genesymbol", referenceGeneFile=refFile,
                            referenceGeneType="genesymbol", isOutput=TRUE,
                            outputDirectory="~/bin/data_temp/", projectName=NULL)
# Out:
# Loading the functional categories...
# Loading the ID list...
# Loading the reference list...
# Summarizing the input ID list by GO Slim data...
# Performing the enrichment analysis...
# Warning message in oraEnrichment(interestGeneList, referenceGeneList, geneSet, minNum = minNum, :
# “No significant gene set is identified based on FDR 0.05!”

# %% [markdown]
# Run with SNP list

# %%
refFile <- system.file("extdata", "referenceGenes.txt", package="WebGestaltR")
enrichResult <- WebGestaltR(enrichMethod="ORA", organism="hsapiens",
                            enrichDatabase="pathway_KEGG", interestGeneFile="~/bin/data_temp/PDSNPs_sorted.txt",
                            interestGeneType="dbSNP", referenceGeneFile=refFile,
                            referenceGeneType="genesymbol", isOutput=TRUE,
                            outputDirectory="~/bin/data_temp/", projectName=NULL)
# Out:
# Loading the functional categories...
# Loading the ID list...
# Loading the reference list...
# Summarizing the input ID list by GO Slim data...
# Performing the enrichment analysis...
# Warning message in oraEnrichment(interestGeneList, referenceGeneList, geneSet, minNum = minNum, :
# “No significant gene set is identified based on FDR 0.05!”

# %% [markdown]
# ## Run WebGestaltR Gene Set Enrichment Analysis

# %%
#Run with original pvalues
rankFile <- system.file("extdata", "GeneRankList.rnk", package="WebGestaltR")
enrichResult <- WebGestaltR(enrichMethod="GSEA", organism="hsapiens",
enrichDatabase="geneontology_Biological_Process_noRedundant", interestGeneFile="~/bin/data_temp/PDgenes_sorted_pvals.rnk",
interestGeneType="genesymbol", sigMethod="top", topThr=10, minNum=5,
outputDirectory="~/bin/data_temp")
# Out:
# Loading the functional categories...
# Loading the ID list...
# Summarizing the uploaded ID list by GO Slim data...
# Performing the enrichment analysis...
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0000041
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0000075
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0000209
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0000910
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001101
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001503
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001525
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001539
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001655
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001667
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001763
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001764
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001818
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001819
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001906
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001963
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002237
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002244
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002250
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002269
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002285
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002440
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002446
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002449
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002521
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002526
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002532
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002576
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002683
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002697
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0003012
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0003013
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006091
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006109
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006260
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006289
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006302
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006308
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006310
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006338
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006352
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006353
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006360
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006397
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006401
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006413
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006457
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006520
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006575
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006631
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006638
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006643
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006720
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006766
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006790
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006814
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006839
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006909
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006925
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006959
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006968
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006970
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006979
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007006
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007015
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007018
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007033
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007034
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007050
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007059
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007162
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007163
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007178
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007187
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007212
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007215
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007219
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007229
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007249
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007271
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007272
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007274
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007369
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007389
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007498
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007517
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007548
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007568
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007586
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007626
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007631
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0008202
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0008213
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0008277
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0008380
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0008544
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0008637
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009100
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009123
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009132
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009141
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009266
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009268
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009308
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009314
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009410
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009581
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009582
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009593
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009595
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009612
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009615
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009743
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009755
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009914
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010171
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010498
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010644
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010657
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010737
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010821
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010876
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010948
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0014812
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015695
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015696
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015698
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015711
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015748
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015837
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015844
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015849
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015850
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015893
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0016042
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0016051
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0016052
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0016053
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0016311
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0016358
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0016999
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0017038
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0017156
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0018195
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0018205
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0018210
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0019080
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0019216
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0019233
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0019748
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0019882
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0019932
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0021510
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0021700
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0021953
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0022406
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0022412
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0022613
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0022616
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030048
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030099
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030522
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030534
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030705
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030900
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030901
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030902
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031098
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031099
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031109
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031128
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031214
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031349
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031503
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031589
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031644
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031647
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031667
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032102
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032103
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032259
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032355
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032409
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032528
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032609
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032612
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032613
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032620
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032635
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032637
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032886
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032941
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032963
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032970
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032984
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0033002
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0033028
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0033044
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0033500
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0033555
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0033619
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0033865
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034067
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034248
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034330
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034340
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034341
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034394
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034612
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034764
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034976
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035249
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035265
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035418
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035637
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035640
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035690
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035821
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035966
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0036119
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0036230
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0036297
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0036314
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0038034
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0038061
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0038127
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0040013
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042092
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042113
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042116
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042180
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042326
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042398
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042445
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042476
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042490
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042558
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042692
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042737
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042770
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042982
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043062
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043087
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043254
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043270
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043279
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043491
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043543
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043583
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043620
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043900
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043954
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0044070
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0044262
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0044282
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0044706
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0044772
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0044843
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045088
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045117
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045165
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045444
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045787
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045861
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045926
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045927
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045930
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0046390
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0046434
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0046677
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0046683
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0046717
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0046847
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048008
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048010
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048013
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048017
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048284
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048285
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048511
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048545
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048568
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048678
# ”
# ...
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0060759
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0061025
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0061351
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0061448
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0061458
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0061512
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0061564
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0061919
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0062012
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0070085
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0070371
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0070482
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0070555
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0070585
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0070661
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0070841
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0070972
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071103
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071216
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071526
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071542
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071559
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071706
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071774
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071824
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071825
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071826
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071867
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071887
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072089
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072331
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072347
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072348
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072376
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072507
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072522
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072524
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072665
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090130
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090150
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090287
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090305
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090382
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090559
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090596
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097066
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097164
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097191
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097193
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097194
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097305
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097485
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097581
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097696
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0098542
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0098656
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0098732
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0098739
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0098742
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0098780
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0098876
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0099072
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0104004
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0106027
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0150076
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0198738
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901136
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901293
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901342
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901568
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901652
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901657
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901987
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901998
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1902115
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1902532
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1902579
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1902600
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1902903
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1903008
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1903034
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1903311
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1903320
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1903509
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1903706
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1903828
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1904950
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1905475
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1990089
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1990868
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:2001020
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:2001057
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:2001233
# ”
# 1000 permutations of score complete...
# Begin affinity propagation...
# End affinity propagation...
# Begin weighted set cover...
# Remain is 0, ending weighted set cover
# Generate the final report...
# Results can be found in the ~/bin/data_temp/Project_1620831213!

# %%
system('ls ~/bin/data_temp/Project_1620831213', intern = TRUE)
# Out:
#  [1] "enriched_geneset_ap_clusters_1620831213.txt"
#  [2] "enriched_geneset_wsc_topsets_1620831213.txt"
#  [3] "enrichment_results_1620831213.txt"
#  [4] "goslim_summary_1620831213_bp.txt"
#  [5] "goslim_summary_1620831213_cc.txt"
#  [6] "goslim_summary_1620831213_mf.txt"
#  [7] "goslim_summary_1620831213.png"
#  [8] "interestingID_mappingTable_1620831213.txt"
#  [9] "interestingID_unmappedList_1620831213.txt"
# [10] "Project_1620831213_GSEA"
# [11] "Project_1620831213_GSEA.rnk"
# [12] "Project_1620831213.zip"
# [13] "Report_1620831213.html"

# %% [markdown]
# Write results to workspace bucket

# %%
shell_do(str_glue('gsutil -u {BILLING_PROJECT_ID} cp -r ~/bin/data_temp/Project_1620831213/goslim_summary_1620831213.png {WORKSPACE_BUCKET}'))
# Out:
# [1] "Executing:  gsutil -u gp2-ipdgc-hackathon cp -r ~/bin/data_temp/Project_1620831213/goslim_summary_1620831213.png gs://fc-secure-b9f9d17f-b38c-407d-85e0-7a759f13cea0"
# character(0)

# %%
#Run with -log10 pvalues
rankFile <- system.file("extdata", "GeneRankList.rnk", package="WebGestaltR")
enrichResult <- WebGestaltR(enrichMethod="GSEA", organism="hsapiens",
enrichDatabase="geneontology_Biological_Process_noRedundant", interestGeneFile="~/bin/data_temp/PDgenes_sorted_pvals_neglog.rnk",
interestGeneType="genesymbol", sigMethod="top", topThr=10, minNum=5,
outputDirectory="~/bin/data_temp")
# Out:
# Loading the functional categories...
# Loading the ID list...
# Summarizing the uploaded ID list by GO Slim data...
# Performing the enrichment analysis...
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0000041
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0000075
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0000209
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0000910
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001101
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001503
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001525
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001539
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001655
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001667
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001763
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001764
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001818
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001819
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001906
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0001963
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002237
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002244
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002250
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002269
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002285
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002440
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002446
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002449
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002521
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002526
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002532
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002576
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002683
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0002697
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0003012
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0003013
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006091
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006109
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006260
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006289
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006302
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006308
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006310
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006338
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006352
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006353
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006360
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006397
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006401
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006413
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006457
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006520
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006575
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006631
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006638
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006643
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006720
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006766
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006790
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006814
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006839
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006909
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006925
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006959
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006968
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006970
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0006979
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007006
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007015
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007018
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007033
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007034
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007050
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007059
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007162
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007163
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007178
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007187
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007212
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007215
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007219
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007229
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007249
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007271
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007272
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007274
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007369
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007389
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007498
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007517
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007548
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007568
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007586
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007626
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0007631
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0008202
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0008213
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0008277
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0008380
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0008544
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0008637
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009100
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009123
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009132
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009141
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009266
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009268
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009308
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009314
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009410
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009581
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009582
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009593
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009595
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009612
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009615
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009743
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009755
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0009914
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010171
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010498
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010644
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010657
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010737
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010821
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010876
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0010948
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0014812
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015695
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015696
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015698
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015711
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015748
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015837
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015844
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015849
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015850
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0015893
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0016042
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0016051
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0016052
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0016053
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0016311
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0016358
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0016999
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0017038
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0017156
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0018195
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0018205
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0018210
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0019080
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0019216
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0019233
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0019748
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0019882
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0019932
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0021510
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0021700
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0021953
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0022406
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0022412
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0022613
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0022616
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030048
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030099
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030522
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030534
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030705
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030900
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030901
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0030902
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031098
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031099
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031109
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031128
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031214
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031349
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031503
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031589
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031644
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031647
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0031667
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032102
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032103
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032259
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032355
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032409
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032528
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032609
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032612
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032613
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032620
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032635
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032637
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032886
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032941
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032963
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032970
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0032984
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0033002
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0033028
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0033044
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0033500
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0033555
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0033619
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0033865
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034067
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034248
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034330
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034340
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034341
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034394
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034612
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034764
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0034976
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035249
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035265
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035418
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035637
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035640
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035690
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035821
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0035966
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0036119
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0036230
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0036297
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0036314
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0038034
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0038061
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0038127
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0040013
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042092
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042113
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042116
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042180
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042326
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042398
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042445
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042476
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042490
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042558
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042692
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042737
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042770
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0042982
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043062
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043087
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043254
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043270
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043279
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043491
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043543
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043583
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043620
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043900
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0043954
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0044070
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0044262
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0044282
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0044706
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0044772
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0044843
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045088
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045117
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045165
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045444
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045787
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045861
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045926
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045927
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0045930
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0046390
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0046434
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0046677
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0046683
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0046717
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0046847
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048008
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048010
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048013
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048017
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048284
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048285
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048511
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048545
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048568
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0048678
# ”
# ...
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0060759
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0061025
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0061351
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0061448
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0061458
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0061512
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0061564
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0061919
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0062012
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0070085
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0070371
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0070482
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0070555
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0070585
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0070661
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0070841
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0070972
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071103
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071216
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071526
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071542
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071559
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071706
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071774
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071824
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071825
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071826
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071867
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0071887
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072089
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072331
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072347
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072348
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072376
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072507
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072522
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072524
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0072665
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090130
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090150
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090287
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090305
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090382
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090559
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0090596
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097066
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097164
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097191
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097193
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097194
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097305
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097485
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097581
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0097696
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0098542
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0098656
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0098732
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0098739
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0098742
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0098780
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0098876
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0099072
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0104004
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0106027
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0150076
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:0198738
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901136
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901293
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901342
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901568
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901652
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901657
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901987
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1901998
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1902115
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1902532
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1902579
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1902600
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1902903
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1903008
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1903034
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1903311
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1903320
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1903509
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1903706
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1903828
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1904950
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1905475
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1990089
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:1990868
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:2001020
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:2001057
# ”
# Warning message in swGsea(inputDf, thresh_type = "val", perms = perNum, min_set_size = minNum, :
# “score does not contain minimum number of items in set for GO:2001233
# ”
# 1000 permutations of score complete...
# Begin affinity propagation...
# End affinity propagation...
# Begin weighted set cover...
# Remain is 0, ending weighted set cover
# Generate the final report...
# Results can be found in the ~/bin/data_temp/Project_1620831683!

# %%
#Look at the files in the results folder
system('ls ~/bin/data_temp/Project_1620831683', intern = TRUE)
# Out:
#  [1] "enriched_geneset_ap_clusters_1620831683.txt"
#  [2] "enriched_geneset_wsc_topsets_1620831683.txt"
#  [3] "enrichment_results_1620831683.txt"
#  [4] "goslim_summary_1620831683_bp.txt"
#  [5] "goslim_summary_1620831683_cc.txt"
#  [6] "goslim_summary_1620831683_mf.txt"
#  [7] "goslim_summary_1620831683.png"
#  [8] "interestingID_mappingTable_1620831683.txt"
#  [9] "interestingID_unmappedList_1620831683.txt"
# [10] "Project_1620831683_GSEA"
# [11] "Project_1620831683_GSEA.rnk"
# [12] "Project_1620831683.zip"
# [13] "Report_1620831683.html"

# %% [markdown]
# Write results to workspace bucket

# %%
shell_do(str_glue('gsutil -u {BILLING_PROJECT_ID} cp -r ~/bin/data_temp/Project_1620831683/goslim_summary_1620831683.png {WORKSPACE_BUCKET}'))
# Out:
# [1] "Executing:  gsutil -u gp2-ipdgc-hackathon cp -r ~/bin/data_temp/Project_1620831683/goslim_summary_1620831683.png gs://fc-secure-b9f9d17f-b38c-407d-85e0-7a759f13cea0"
# character(0)
